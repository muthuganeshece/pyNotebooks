# %%
import pandas as pd

# %%
train_data = 'train_FD002.txt'
test_data = 'test_FD002.txt'

# %%
raw_data = pd.read_csv('E:/Nextstep/MLProjects/YTS/PredictiveMaintenance/Datasets/NASAJetEngine/CMaps/' + train_data, sep = ' ', header = None)

# %%
raw_data.dropna(axis=1, inplace=True)

# %%
col_names = ['Sensor' + str(i) for i in range(1, len(raw_data.columns)-1)]

# %%
col_names.insert(0,['Engine', 'Cycles'])
col_names
# Out:
# [['Engine', 'Cycles'],
#  'Sensor1',
#  'Sensor2',
#  'Sensor3',
#  'Sensor4',
#  'Sensor5',
#  'Sensor6',
#  'Sensor7',
#  'Sensor8',
#  'Sensor9',
#  'Sensor10',
#  'Sensor11',
#  'Sensor12',
#  'Sensor13',
#  'Sensor14',
#  'Sensor15',
#  'Sensor16',
#  'Sensor17',
#  'Sensor18',
#  'Sensor19',
#  'Sensor20',
#  'Sensor21',
#  'Sensor22',
#  'Sensor23',
#  'Sensor24',
#  'Sensor25',
#  'Sensor26']

# %%
raw_data.columns = col_names
raw_data
# Out:
#        Engine  Cycles  Sensor1  Sensor2  Sensor3  Sensor4  Sensor5  Sensor6  \
# 0           1       1  34.9983   0.8400    100.0   449.44   555.32  1358.61
# 1           1       2  41.9982   0.8408    100.0   445.00   549.90  1353.22
# 2           1       3  24.9988   0.6218     60.0   462.54   537.31  1256.76
# 3           1       4  42.0077   0.8416    100.0   445.00   549.51  1354.03
# 4           1       5  25.0005   0.6203     60.0   462.54   537.07  1257.71
# ...       ...     ...      ...      ...      ...      ...      ...      ...
# 53754     260     312  20.0037   0.7000    100.0   491.19   608.79  1495.60
# 53755     260     313  10.0022   0.2510    100.0   489.05   605.81  1514.32
# 53756     260     314  25.0041   0.6200     60.0   462.54   537.48  1276.24
# 53757     260     315  25.0033   0.6220     60.0   462.54   537.84  1272.95
# 53758     260     316  35.0036   0.8400    100.0   449.44   556.64  1374.61
#
# ...

# %%
temp_df = raw_data[['Engine', 'Cycles']].groupby('Engine').max()
#temp_df = raw_data.loc[lst]

# %%
raw_data = raw_data.merge(temp_df, how='left', on = 'Engine')
raw_data.rename(columns={'Cycles_y': 'Remaining Cycles'}, inplace=True)
raw_data.drop('Cycles_x', axis=1)
# Out:
#        Engine  Sensor1  Sensor2  Sensor3  Sensor4  Sensor5  Sensor6  Sensor7  \
# 0           1  34.9983   0.8400    100.0   449.44   555.32  1358.61  1137.23
# 1           1  41.9982   0.8408    100.0   445.00   549.90  1353.22  1125.78
# 2           1  24.9988   0.6218     60.0   462.54   537.31  1256.76  1047.45
# 3           1  42.0077   0.8416    100.0   445.00   549.51  1354.03  1126.38
# 4           1  25.0005   0.6203     60.0   462.54   537.07  1257.71  1047.93
# ...       ...      ...      ...      ...      ...      ...      ...      ...
# 53754     260  20.0037   0.7000    100.0   491.19   608.79  1495.60  1269.51
# 53755     260  10.0022   0.2510    100.0   489.05   605.81  1514.32  1324.12
# 53756     260  25.0041   0.6200     60.0   462.54   537.48  1276.24  1057.92
# 53757     260  25.0033   0.6220     60.0   462.54   537.84  1272.95  1066.30
# 53758     260  35.0036   0.8400    100.0   449.44   556.64  1374.61  1145.52
#
# ...

# %%
raw_data
# Out:
#        Engine  Cycles_x  Sensor1  Sensor2  Sensor3  Sensor4  Sensor5  Sensor6  \
# 0           1         1  34.9983   0.8400    100.0   449.44   555.32  1358.61
# 1           1         2  41.9982   0.8408    100.0   445.00   549.90  1353.22
# 2           1         3  24.9988   0.6218     60.0   462.54   537.31  1256.76
# 3           1         4  42.0077   0.8416    100.0   445.00   549.51  1354.03
# 4           1         5  25.0005   0.6203     60.0   462.54   537.07  1257.71
# ...       ...       ...      ...      ...      ...      ...      ...      ...
# 53754     260       312  20.0037   0.7000    100.0   491.19   608.79  1495.60
# 53755     260       313  10.0022   0.2510    100.0   489.05   605.81  1514.32
# 53756     260       314  25.0041   0.6200     60.0   462.54   537.48  1276.24
# 53757     260       315  25.0033   0.6220     60.0   462.54   537.84  1272.95
# 53758     260       316  35.0036   0.8400    100.0   449.44   556.64  1374.61
#
# ...
